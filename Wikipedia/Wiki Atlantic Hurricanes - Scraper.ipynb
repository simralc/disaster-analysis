# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
pltWidth, pltHeight = 20, 10
plt.rcParams['figure.figsize'] = (pltWidth, pltHeight)

# %%
url = "https://en.wikipedia.org/wiki/List_of_costliest_Atlantic_hurricanes"
html_string = requests.get(url).content

# %%
soup = BeautifulSoup(html_string, 'html.parser')
table = soup.find('table')

# %%
columns = ['Name', 'Damage in Billions USD', 'Season',
           'Storm classification at peak intensity']

num_rows = len(table.find_all('tr'))
hurricaneDf = pd.DataFrame(columns=range(4), index=range(num_rows-1))

for row_marker, row in enumerate(table.find_all('tr')[1:]):
    Name = row.find('th').text
    hurricaneDf.iat[row_marker, 0] = Name

    for column_marker, column in enumerate(row.find_all('td')[:3]):
        if column_marker != 1:
            hurricaneDf.iat[row_marker, column_marker+1] = column.find('span', class_='sorttext').text
        else:
            hurricaneDf.iat[row_marker, column_marker+1] = column.find('a').text

hurricaneDf.columns = columns

# %%
hurricaneDf['Season'] = hurricaneDf['Season'].apply(lambda x: int(x))
hurricaneDf['Damage in Billions USD'] = hurricaneDf['Damage in Billions USD'].apply(lambda x: float(x[1:]))

# %%
hurricaneDf
# Out:
#         Name  Damage in Billions USD  Season  \
# 0    Katrina                  125.00    2005
# 1     Harvey                  125.00    2017
# 2      Maria                   91.60    2017
# 3      Sandy                   68.70    2012
# 4       Irma                   64.80    2017
# 5        Ike                   38.00    2008
# 6      Wilma                   27.40    2005
# 7     Andrew                   27.30    1992
# 8       Ivan                   26.10    2004
# 9       Rita                   18.50    2005
# 10   Charley                   16.90    2004
# 11   Matthew                   15.10    2016
# 12     Irene                   14.20    2011
# 13   Frances                   10.10    2004
# 14      Hugo                    9.47    1989
# 15   Georges                    9.37    1998
# 16   Allison                    8.50    2001
# 17    Gustav                    8.31    2008
# 18    Jeanne                    7.94    2004
# 19     Floyd                    6.50    1999
# 20     Mitch                    6.08    1998
# 21    Isabel                    5.50    2003
# 22      Fran                    5.00    1996
# 23      Opal                    4.70    1995
# 24      Stan                    3.96    2005
# 25     Karl                     3.90    2010
# 26    Dennis                    3.98    2005
# 27    Isaac                     3.11    2012
# 28    Alicia                    3.00    1983
# 29   Gilbert                    2.98    1988
# 30      Luis                    2.97    1995
# 31      Lee                     2.80    2011
# 32  Michelle                    2.35    2001
# 33   Marilyn                    2.10    1995
# 34     Agnes                    2.10    1972
# 35      Dean                    1.95    2007
# 36      Joan                    1.87    1988
# 37      Fifi                    1.80    1974
# 38  Frederic                    1.77    1979
# 39    Dolly                     1.60    2008
# 40     Allen                    1.57    1980
# 41     David                    1.54    1979
# 42     Alex                     1.52    2010
# 43     Juan                     1.50    1985
# 44       Bob                    1.50    1991
# 45   Roxanne                    1.50    1995
# 46    Ingrid                    1.50    2013
# 47     Betsy                    1.43    1965
# 48   Camille                    1.43    1969
# 49     Elena                    1.30    1985
# 50   Isidore                    1.28    2002
# 51      Lili                    1.16    2002
# 52  Alberto                     1.03    1994
# 53    Emily                     1.01    2005
# 54   Bonnie                     1.00    1998
#
#    Storm classification at peak intensity
# 0                    Category 5 hurricane
# 1                    Category 4 hurricane
# 2                    Category 5 hurricane
# 3                    Category 3 hurricane
# 4                    Category 5 hurricane
# 5                    Category 4 hurricane
# 6                    Category 5 hurricane
# 7                    Category 5 hurricane
# 8                    Category 5 hurricane
# 9                    Category 5 hurricane
# 10                   Category 4 hurricane
# 11                   Category 5 hurricane
# 12                   Category 3 hurricane
# 13                   Category 4 hurricane
# 14                   Category 5 hurricane
# 15                   Category 4 hurricane
# 16                         Tropical storm
# 17                   Category 4 hurricane
# 18                   Category 3 hurricane
# 19                   Category 4 hurricane
# 20                   Category 5 hurricane
# 21                   Category 5 hurricane
# 22                   Category 3 hurricane
# 23                   Category 4 hurricane
# 24                   Category 1 hurricane
# 25                   Category 3 hurricane
# 26                   Category 4 hurricane
# 27                   Category 1 hurricane
# 28                   Category 3 hurricane
# 29                   Category 5 hurricane
# 30                   Category 4 hurricane
# 31                         Tropical storm
# 32                   Category 4 hurricane
# 33                   Category 3 hurricane
# 34                   Category 1 hurricane
# 35                   Category 5 hurricane
# 36                   Category 4 hurricane
# 37                   Category 2 hurricane
# 38                   Category 4 hurricane
# 39                   Category 2 hurricane
# 40                   Category 5 hurricane
# 41                   Category 5 hurricane
# 42                   Category 2 hurricane
# 43                   Category 1 hurricane
# 44                   Category 3 hurricane
# 45                   Category 3 hurricane
# 46                   Category 1 hurricane
# 47                   Category 4 hurricane
# 48                   Category 5 hurricane
# 49                   Category 3 hurricane
# 50                   Category 3 hurricane
# 51                   Category 4 hurricane
# 52                         Tropical storm
# 53                   Category 5 hurricane
# 54                   Category 3 hurricane

# %%
hurricane = hurricaneDf.sort_values(ascending=False, by='Season')
plt.bar(range(hurricane.shape[0]), hurricane['Damage in Billions USD'])
plt.xticks(range(hurricane.shape[0]), hurricane['Name'], rotation=90)
plt.ylabel('in Billion USD')

plt.show()

# %%
Name = hurricaneDf['Name'].tolist()
Season = hurricaneDf['Season'].tolist()

# %%
List = zip(Name, Season)
[print(x) for x in List];
# Out:
# ('Katrina', 2005)
# ('Harvey', 2017)
# ('Maria', 2017)
# ('Sandy', 2012)
# ('Irma', 2017)
# ('Ike', 2008)
# ('Wilma', 2005)
# ('Andrew', 1992)
# ('Ivan', 2004)
# ('Rita', 2005)
# ('Charley', 2004)
# ('Matthew', 2016)
# ('Irene', 2011)
# ('Frances', 2004)
# ('Hugo', 1989)
# ('Georges', 1998)
# ('Allison', 2001)
# ('Gustav', 2008)
# ('Jeanne', 2004)
# ('Floyd', 1999)
# ('Mitch', 1998)
# ('Isabel', 2003)
# ('Fran', 1996)
# ('Opal', 1995)
# ('Stan', 2005)
# ('Karl ', 2010)
# ('Dennis', 2005)
# ('Isaac ', 2012)
# ('Alicia', 1983)
# ('Gilbert', 1988)
# ('Luis', 1995)
# ('Lee ', 2011)
# ('Michelle', 2001)
# ('Marilyn', 1995)
# ('Agnes', 1972)
# ('Dean', 2007)
# ('Joan', 1988)
# ('Fifi', 1974)
# ('Frederic', 1979)
# ('Dolly ', 2008)
# ('Allen', 1980)
# ('David', 1979)
# ('Alex ', 2010)
# ('Juan ', 1985)
# ('Bob', 1991)
# ('Roxanne', 1995)
# ('Ingrid', 2013)
# ('Betsy', 1965)
# ('Camille', 1969)
# ('Elena', 1985)
# ('Isidore', 2002)
# ('Lili', 2002)
# ('Alberto ', 1994)
# ('Emily ', 2005)
# ('Bonnie ', 1998)
